# %% [markdown]
# <a href="https://colab.research.google.com/github/kalebmes/CS376-Machine-Learning/blob/main/CS376_project_demo2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#install necessary modules
# !pip install kaggle
# !pip install timm
# Out:
# Requirement already satisfied: kaggle in /usr/local/lib/python3.7/dist-packages (1.5.12)
# Requirement already satisfied: python-slugify in /usr/local/lib/python3.7/dist-packages (from kaggle) (6.1.2)
# Requirement already satisfied: six>=1.10 in /usr/local/lib/python3.7/dist-packages (from kaggle) (1.15.0)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.7/dist-packages (from kaggle) (1.24.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from kaggle) (4.64.0)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.7/dist-packages (from kaggle) (2.8.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from kaggle) (2.23.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.7/dist-packages (from kaggle) (2021.10.8)
# Requirement already satisfied: text-unidecode>=1.3 in /usr/local/lib/python3.7/dist-packages (from python-slugify->kaggle) (1.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->kaggle) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->kaggle) (2.10)
# Requirement already satisfied: timm in /usr/local/lib/python3.7/dist-packages (0.5.4)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.7/dist-packages (from timm) (0.12.0+cu113)
# Requirement already satisfied: torch>=1.4 in /usr/local/lib/python3.7/dist-packages (from timm) (1.11.0+cu113)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch>=1.4->timm) (4.2.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from torchvision->timm) (1.21.6)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.7/dist-packages (from torchvision->timm) (7.1.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from torchvision->timm) (2.23.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->torchvision->timm) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->torchvision->timm) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->torchvision->timm) (2021.10.8)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->torchvision->timm) (2.10)

# %%
#mount your drive first - you can do it once
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#before executing the code cell below, first download the 'kaggle.json' file from your kaggle's account and upload it to your drive:
#steps
#go to https://www.kaggle.com/<your-kaggle-username>/account -> example.... kaggle.com/kalebasfaw/account
#then ctrl + F => 'create new API token'
#then after downloading that file, upload it to your google drive

# %%
# !mkdir ~/.kaggle
# !cp /content/drive/MyDrive/kaggle.json ~/.kaggle/kaggle.json
# Out:
# mkdir: cannot create directory ‘/root/.kaggle’: File exists

# %%
! kaggle competitions download challenges-in-representation-learning-facial-expression-recognition-challenge
# Out:
# Downloading challenges-in-representation-learning-facial-expression-recognition-challenge.zip to /content
#  93% 265M/285M [00:11<00:01, 18.9MB/s]
# 100% 285M/285M [00:11<00:00, 26.7MB/s]

# %%
#let's get the csv files from the zip file
data_path = "/content/challenges-in-representation-learning-facial-expression-recognition-challenge.zip"
from zipfile import ZipFile
with ZipFile(data_path) as myzip:
  train_data = myzip.open('train.csv')
  test_data = myzip.open('test.csv') #this is used for testing the data, it doesn't contain the labels

# %%
#importing necessary modules
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import DataLoader, Dataset
from PIL import Image
import os
import torchvision.datasets as dset
import torchvision.transforms as T

# %%
#loading our data into pandas data frame
train_df = pd.read_csv(train_data)
test_df = pd.read_csv(test_data) #not used for this task, only for testing, and ranking

# %%
#shuffle indices into training set and test sets and separate the validation data from the training data
from sklearn.model_selection import train_test_split
X_train, X_val, y_train, y_val = train_test_split(train_df['pixels'], train_df['emotion'], test_size=0.2, shuffle=True)

# %%
#convert each of the training and the validation datasets into dataframes
new_train = pd.DataFrame(data=X_train)
new_train['emotion'] = y_train
new_val = pd.DataFrame(data=X_val)
new_val['emotion'] = y_val

# %%
#now make directories to store each of the images of each categories from the pixels
os.mkdir('/content/fer_images')
os.mkdir('/content/fer_images/train')
os.mkdir('/content/fer_images/validation')

# %%
#WARNING - EXECUTE THIS CELL ONLY ONCE, create a directory of each of the emotions
em_dict = {0: 'angry', 1: 'sad', 2: 'happy', 3: 'neutral', 4: 'disgust', 5: 'fear', 6: 'surprise'}
fer_path = os.path.join('/content', 'fer_images')
os.chdir(fer_path)
train_path = os.path.join(fer_path, 'train')
validation_path = os.path.join(fer_path, 'validation')
for key in em_dict.keys():
  os.chdir(train_path)
  os.mkdir(em_dict[key])
  os.chdir(validation_path)
  os.mkdir(em_dict[key])

# %%
#save the images into each of the folders of their respective emotions
##saving each images on the training set
counter_each = {'angry': 0, 'sad': 0, 'happy': 0, 'neutral': 0, 'disgust': 0, 'fear': 0, 'surprise': 0}
for (ind, row) in new_train.iterrows():
  emotion = em_dict[row['emotion']]
  emotion_path = os.path.join(train_path, emotion)
  img = np.fromstring(row['pixels'], dtype='uint8', sep=' ')
  img = img.reshape((48, 48))
  image = Image.fromarray(img)
  counter_each[emotion] += 1
  filename = f'{emotion}{counter_each[emotion]}.jpg'
  image_path = os.path.join(emotion_path, filename)
  image.save(image_path)
  print('saved: ', filename, 'in the training set on the path: ', image_path)
# Out:
# Streaming output truncated to the last 5000 lines.
# saved:  surprise3133.jpg in the training set on the path:  /content/fer_images/train/surprise/surprise3133.jpg
# saved:  disgust3079.jpg in the training set on the path:  /content/fer_images/train/disgust/disgust3079.jpg
# saved:  neutral4456.jpg in the training set on the path:  /content/fer_images/train/neutral/neutral4456.jpg
# saved:  surprise3134.jpg in the training set on the path:  /content/fer_images/train/surprise/surprise3134.jpg
# saved:  fear1974.jpg in the training set on the path:  /content/fer_images/train/fear/fear1974.jpg
# saved:  neutral4457.jpg in the training set on the path:  /content/fer_images/train/neutral/neutral4457.jpg
# saved:  angry2491.jpg in the training set on the path:  /content/fer_images/train/angry/angry2491.jpg
# saved:  angry2492.jpg in the training set on the path:  /content/fer_images/train/angry/angry2492.jpg
# saved:  surprise3135.jpg in the training set on the path:  /content/fer_images/train/surprise/surprise3135.jpg
# saved:  surprise3136.jpg in the training set on the path:  /content/fer_images/train/surprise/surprise3136.jpg
# saved:  happy2551.jpg in the training set on the path:  /content/fer_images/train/happy/happy2551.jpg
# saved:  disgust3080.jpg in the training set on the path:  /content/fer_images/train/disgust/disgust3080.jpg
# saved:  neutral4458.jpg in the training set on the path:  /content/fer_images/train/neutral/neutral4458.jpg
# saved:  neutral4459.jpg in the training set on the path:  /content/fer_images/train/neutral/neutral4459.jpg
# saved:  angry2493.jpg in the training set on the path:  /content/fer_images/train/angry/angry2493.jpg
# saved:  angry2494.jpg in the training set on the path:  /content/fer_images/train/angry/angry2494.jpg
# saved:  surprise3137.jpg in the training set on the path:  /content/fer_images/train/surprise/surprise3137.jpg
# saved:  fear1975.jpg in the training set on the path:  /content/fer_images/train/fear/fear1975.jpg
# saved:  neutral4460.jpg in the training set on the path:  /content/fer_images/train/neutral/neutral4460.jpg
# saved:  neutral4461.jpg in the training set on the path:  /content/fer_images/train/neutral/neutral4461.jpg
# saved:  neutral4462.jpg in the training set on the path:  /content/fer_images/train/neutral/neutral4462.jpg
# saved:  fear1976.jpg in the training set on the path:  /content/fer_images/train/fear/fear1976.jpg
# saved:  neutral4463.jpg in the training set on the path:  /content/fer_images/train/neutral/neutral4463.jpg
# saved:  fear1977.jpg in the training set on the path:  /content/fer_images/train/fear/fear1977.jpg
# saved:  surprise3138.jpg in the training set on the path:  /content/fer_images/train/surprise/surprise3138.jpg
# saved:  neutral4464.jpg in the training set on the path:  /content/fer_images/train/neutral/neutral4464.jpg
# saved:  neutral4465.jpg in the training set on the path:  /content/fer_images/train/neutral/neutral4465.jpg
# saved:  angry2495.jpg in the training set on the path:  /content/fer_images/train/angry/angry2495.jpg
# saved:  angry2496.jpg in the training set on the path:  /content/fer_images/train/angry/angry2496.jpg
# saved:  surprise3139.jpg in the training set on the path:  /content/fer_images/train/surprise/surprise3139.jpg
# saved:  surprise3140.jpg in the training set on the path:  /content/fer_images/train/surprise/surprise3140.jpg
# saved:  fear1978.jpg in the training set on the path:  /content/fer_images/train/fear/fear1978.jpg
# saved:  surprise3141.jpg in the training set on the path:  /content/fer_images/train/surprise/surprise3141.jpg
# saved:  sad290.jpg in the training set on the path:  /content/fer_images/train/sad/sad290.jpg
# saved:  disgust3081.jpg in the training set on the path:  /content/fer_images/train/disgust/disgust3081.jpg
# saved:  angry2497.jpg in the training set on the path:  /content/fer_images/train/angry/angry2497.jpg
# saved:  surprise3142.jpg in the training set on the path:  /content/fer_images/train/surprise/surprise3142.jpg
# saved:  angry2498.jpg in the training set on the path:  /content/fer_images/train/angry/angry2498.jpg
# saved:  disgust3082.jpg in the training set on the path:  /content/fer_images/train/disgust/disgust3082.jpg
# saved:  disgust3083.jpg in the training set on the path:  /content/fer_images/train/disgust/disgust3083.jpg
# saved:  happy2552.jpg in the training set on the path:  /content/fer_images/train/happy/happy2552.jpg
# saved:  neutral4466.jpg in the training set on the path:  /content/fer_images/train/neutral/neutral4466.jpg
# saved:  neutral4467.jpg in the training set on the path:  /content/fer_images/train/neutral/neutral4467.jpg
# saved:  angry2499.jpg in the training set on the path:  /content/fer_images/train/angry/angry2499.jpg
# saved:  happy2553.jpg in the training set on the path:  /content/fer_images/train/happy/happy2553.jpg
# saved:  neutral4468.jpg in the training set on the path:  /content/fer_images/train/neutral/neutral4468.jpg
# saved:  neutral4469.jpg in the training set on the path:  /content/fer_images/train/neutral/neutral4469.jpg
# saved:  fear1979.jpg in the training set on the path:  /content/fer_images/train/fear/fear1979.jpg
# saved:  fear1980.jpg in the training set on the path:  /content/fer_images/train/fear/fear1980.jpg
# saved:  surprise3143.jpg in the training set on the path:  /content/fer_images/train/surprise/surprise3143.jpg
# saved:  angry2500.jpg in the training set on the path:  /content/fer_images/train/angry/angry2500.jpg
# saved:  surprise3144.jpg in the training set on the path:  /content/fer_images/train/surprise/surprise3144.jpg
# saved:  angry2501.jpg in the training set on the path:  /content/fer_images/train/angry/angry2501.jpg
# saved:  angry2502.jpg in the training set on the path:  /content/fer_images/train/angry/angry2502.jpg
# saved:  surprise3145.jpg in the training set on the path:  /content/fer_images/train/surprise/surprise3145.jpg
# saved:  angry2503.jpg in the training set on the path:  /content/fer_images/train/angry/angry2503.jpg
# saved:  neutral4470.jpg in the training set on the path:  /content/fer_images/train/neutral/neutral4470.jpg
# saved:  surprise3146.jpg in the training set on the path:  /content/fer_images/train/surprise/surprise3146.jpg
# saved:  disgust3084.jpg in the training set on the path:  /content/fer_images/train/disgust/disgust3084.jpg
# saved:  fear1981.jpg in the training set on the path:  /content/fer_images/train/fear/fear1981.jpg
# saved:  angry2504.jpg in the training set on the path:  /content/fer_images/train/angry/angry2504.jpg
# saved:  neutral4471.jpg in the training set on the path:  /content/fer_images/train/neutral/neutral4471.jpg
# saved:  surprise3147.jpg in the training set on the path:  /content/fer_images/train/surprise/surprise3147.jpg
# saved:  happy2554.jpg in the training set on the path:  /content/fer_images/train/happy/happy2554.jpg
# saved:  disgust3085.jpg in the training set on the path:  /content/fer_images/train/disgust/disgust3085.jpg
# saved:  neutral4472.jpg in the training set on the path:  /content/fer_images/train/neutral/neutral4472.jpg
# saved:  neutral4473.jpg in the training set on the path:  /content/fer_images/train/neutral/neutral4473.jpg
# saved:  fear1982.jpg in the training set on the path:  /content/fer_images/train/fear/fear1982.jpg
# saved:  surprise3148.jpg in the training set on the path:  /content/fer_images/train/surprise/surprise3148.jpg
# saved:  neutral4474.jpg in the training set on the path:  /content/fer_images/train/neutral/neutral4474.jpg
# saved:  angry2505.jpg in the training set on the path:  /content/fer_images/train/angry/angry2505.jpg
# saved:  surprise3149.jpg in the training set on the path:  /content/fer_images/train/surprise/surprise3149.jpg
# saved:  neutral4475.jpg in the training set on the path:  /content/fer_images/train/neutral/neutral4475.jpg
# saved:  neutral4476.jpg in the training set on the path:  /content/fer_images/train/neutral/neutral4476.jpg
# saved:  disgust3086.jpg in the training set on the path:  /content/fer_images/train/disgust/disgust3086.jpg
# saved:  happy2555.jpg in the training set on the path:  /content/fer_images/train/happy/happy2555.jpg
# saved:  angry2506.jpg in the training set on the path:  /content/fer_images/train/angry/angry2506.jpg
# saved:  happy2556.jpg in the training set on the path:  /content/fer_images/train/happy/happy2556.jpg
# saved:  neutral4477.jpg in the training set on the path:  /content/fer_images/train/neutral/neutral4477.jpg
# saved:  happy2557.jpg in the training set on the path:  /content/fer_images/train/happy/happy2557.jpg
# saved:  neutral4478.jpg in the training set on the path:  /content/fer_images/train/neutral/neutral4478.jpg
# saved:  happy2558.jpg in the training set on the path:  /content/fer_images/train/happy/happy2558.jpg
# saved:  angry2507.jpg in the training set on the path:  /content/fer_images/train/angry/angry2507.jpg
# saved:  happy2559.jpg in the training set on the path:  /content/fer_images/train/happy/happy2559.jpg
# saved:  neutral4479.jpg in the training set on the path:  /content/fer_images/train/neutral/neutral4479.jpg
# saved:  neutral4480.jpg in the training set on the path:  /content/fer_images/train/neutral/neutral4480.jpg
# saved:  surprise3150.jpg in the training set on the path:  /content/fer_images/train/surprise/surprise3150.jpg
# saved:  fear1983.jpg in the training set on the path:  /content/fer_images/train/fear/fear1983.jpg
# saved:  neutral4481.jpg in the training set on the path:  /content/fer_images/train/neutral/neutral4481.jpg
# saved:  happy2560.jpg in the training set on the path:  /content/fer_images/train/happy/happy2560.jpg
# saved:  neutral4482.jpg in the training set on the path:  /content/fer_images/train/neutral/neutral4482.jpg
# saved:  fear1984.jpg in the training set on the path:  /content/fer_images/train/fear/fear1984.jpg
# saved:  neutral4483.jpg in the training set on the path:  /content/fer_images/train/neutral/neutral4483.jpg
# saved:  fear1985.jpg in the training set on the path:  /content/fer_images/train/fear/fear1985.jpg
# saved:  surprise3151.jpg in the training set on the path:  /content/fer_images/train/surprise/surprise3151.jpg
# saved:  happy2561.jpg in the training set on the path:  /content/fer_images/train/happy/happy2561.jpg
# saved:  neutral4484.jpg in the training set on the path:  /content/fer_images/train/neutral/neutral4484.jpg
# saved:  neutral4485.jpg in the training set on the path:  /content/fer_images/train/neutral/neutral4485.jpg
# saved:  neutral4486.jpg in the training set on the path:  /content/fer_images/train/neutral/neutral4486.jpg
# saved:  happy2562.jpg in the training set on the path:  /content/fer_images/train/happy/happy2562.jpg
# saved:  disgust3087.jpg in the training set on the path:  /content/fer_images/train/disgust/disgust3087.jpg
# saved:  angry2508.jpg in the training set on the path:  /content/fer_images/train/angry/angry2508.jpg
# saved:  neutral4487.jpg in the training set on the path:  /content/fer_images/train/neutral/neutral4487.jpg
# saved:  happy2563.jpg in the training set on the path:  /content/fer_images/train/happy/happy2563.jpg
# saved:  neutral4488.jpg in the training set on the path:  /content/fer_images/train/neutral/neutral4488.jpg
# saved:  neutral4489.jpg in the training set on the path:  /content/fer_images/train/neutral/neutral4489.jpg
# saved:  disgust3088.jpg in the training set on the path:  /content/fer_images/train/disgust/disgust3088.jpg
# saved:  neutral4490.jpg in the training set on the path:  /content/fer_images/train/neutral/neutral4490.jpg
# saved:  surprise3152.jpg in the training set on the path:  /content/fer_images/train/surprise/surprise3152.jpg
# saved:  neutral4491.jpg in the training set on the path:  /content/fer_images/train/neutral/neutral4491.jpg
# saved:  fear1986.jpg in the training set on the path:  /content/fer_images/train/fear/fear1986.jpg
# saved:  disgust3089.jpg in the training set on the path:  /content/fer_images/train/disgust/disgust3089.jpg
# saved:  neutral4492.jpg in the training set on the path:  /content/fer_images/train/neutral/neutral4492.jpg
# saved:  neutral4493.jpg in the training set on the path:  /content/fer_images/train/neutral/neutral4493.jpg
# saved:  happy2564.jpg in the training set on the path:  /content/fer_images/train/happy/happy2564.jpg
# saved:  neutral4494.jpg in the training set on the path:  /content/fer_images/train/neutral/neutral4494.jpg
# saved:  disgust3090.jpg in the training set on the path:  /content/fer_images/train/disgust/disgust3090.jpg
# saved:  neutral4495.jpg in the training set on the path:  /content/fer_images/train/neutral/neutral4495.jpg
# saved:  happy2565.jpg in the training set on the path:  /content/fer_images/train/happy/happy2565.jpg
# saved:  surprise3153.jpg in the training set on the path:  /content/fer_images/train/surprise/surprise3153.jpg
# saved:  neutral4496.jpg in the training set on the path:  /content/fer_images/train/neutral/neutral4496.jpg
# saved:  fear1987.jpg in the training set on the path:  /content/fer_images/train/fear/fear1987.jpg
# saved:  disgust3091.jpg in the training set on the path:  /content/fer_images/train/disgust/disgust3091.jpg
# saved:  surprise3154.jpg in the training set on the path:  /content/fer_images/train/surprise/surprise3154.jpg
# saved:  angry2509.jpg in the training set on the path:  /content/fer_images/train/angry/angry2509.jpg
# saved:  happy2566.jpg in the training set on the path:  /content/fer_images/train/happy/happy2566.jpg
# saved:  surprise3155.jpg in the training set on the path:  /content/fer_images/train/surprise/surprise3155.jpg
# saved:  surprise3156.jpg in the training set on the path:  /content/fer_images/train/surprise/surprise3156.jpg
# saved:  angry2510.jpg in the training set on the path:  /content/fer_images/train/angry/angry2510.jpg
# saved:  neutral4497.jpg in the training set on the path:  /content/fer_images/train/neutral/neutral4497.jpg
# saved:  happy2567.jpg in the training set on the path:  /content/fer_images/train/happy/happy2567.jpg
# saved:  happy2568.jpg in the training set on the path:  /content/fer_images/train/happy/happy2568.jpg
# saved:  disgust3092.jpg in the training set on the path:  /content/fer_images/train/disgust/disgust3092.jpg
# saved:  neutral4498.jpg in the training set on the path:  /content/fer_images/train/neutral/neutral4498.jpg
# saved:  surprise3157.jpg in the training set on the path:  /content/fer_images/train/surprise/surprise3157.jpg
# saved:  happy2569.jpg in the training set on the path:  /content/fer_images/train/happy/happy2569.jpg
# saved:  angry2511.jpg in the training set on the path:  /content/fer_images/train/angry/angry2511.jpg
# saved:  angry2512.jpg in the training set on the path:  /content/fer_images/train/angry/angry2512.jpg
# saved:  neutral4499.jpg in the training set on the path:  /content/fer_images/train/neutral/neutral4499.jpg
# saved:  happy2570.jpg in the training set on the path:  /content/fer_images/train/happy/happy2570.jpg
# saved:  surprise3158.jpg in the training set on the path:  /content/fer_images/train/surprise/surprise3158.jpg
# saved:  angry2513.jpg in the training set on the path:  /content/fer_images/train/angry/angry2513.jpg
# saved:  disgust3093.jpg in the training set on the path:  /content/fer_images/train/disgust/disgust3093.jpg
# saved:  happy2571.jpg in the training set on the path:  /content/fer_images/train/happy/happy2571.jpg
# saved:  neutral4500.jpg in the training set on the path:  /content/fer_images/train/neutral/neutral4500.jpg
# saved:  surprise3159.jpg in the training set on the path:  /content/fer_images/train/surprise/surprise3159.jpg
# saved:  fear1988.jpg in the training set on the path:  /content/fer_images/train/fear/fear1988.jpg
# saved:  neutral4501.jpg in the training set on the path:  /content/fer_images/train/neutral/neutral4501.jpg
# saved:  surprise3160.jpg in the training set on the path:  /content/fer_images/train/surprise/surprise3160.jpg
# saved:  fear1989.jpg in the training set on the path:  /content/fer_images/train/fear/fear1989.jpg
# saved:  angry2514.jpg in the training set on the path:  /content/fer_images/train/angry/angry2514.jpg
# saved:  surprise3161.jpg in the training set on the path:  /content/fer_images/train/surprise/surprise3161.jpg
# saved:  surprise3162.jpg in the training set on the path:  /content/fer_images/train/surprise/surprise3162.jpg
# saved:  disgust3094.jpg in the training set on the path:  /content/fer_images/train/disgust/disgust3094.jpg
# saved:  fear1990.jpg in the training set on the path:  /content/fer_images/train/fear/fear1990.jpg
# saved:  neutral4502.jpg in the training set on the path:  /content/fer_images/train/neutral/neutral4502.jpg
# saved:  disgust3095.jpg in the training set on the path:  /content/fer_images/train/disgust/disgust3095.jpg
# saved:  surprise3163.jpg in the training set on the path:  /content/fer_images/train/surprise/surprise3163.jpg
# saved:  fear1991.jpg in the training set on the path:  /content/fer_images/train/fear/fear1991.jpg
# saved:  surprise3164.jpg in the training set on the path:  /content/fer_images/train/surprise/surprise3164.jpg
# saved:  disgust3096.jpg in the training set on the path:  /content/fer_images/train/disgust/disgust3096.jpg
# saved:  angry2515.jpg in the training set on the path:  /content/fer_images/train/angry/angry2515.jpg
# saved:  fear1992.jpg in the training set on the path:  /content/fer_images/train/fear/fear1992.jpg
# saved:  neutral4503.jpg in the training set on the path:  /content/fer_images/train/neutral/neutral4503.jpg
# saved:  fear1993.jpg in the training set on the path:  /content/fer_images/train/fear/fear1993.jpg
# saved:  fear1994.jpg in the training set on the path:  /content/fer_images/train/fear/fear1994.jpg
# saved:  disgust3097.jpg in the training set on the path:  /content/fer_images/train/disgust/disgust3097.jpg
# saved:  neutral4504.jpg in the training set on the path:  /content/fer_images/train/neutral/neutral4504.jpg
# saved:  fear1995.jpg in the training set on the path:  /content/fer_images/train/fear/fear1995.jpg
# saved:  disgust3098.jpg in the training set on the path:  /content/fer_images/train/disgust/disgust3098.jpg
# saved:  surprise3165.jpg in the training set on the path:  /content/fer_images/train/surprise/surprise3165.jpg
# saved:  surprise3166.jpg in the training set on the path:  /content/fer_images/train/surprise/surprise3166.jpg
# saved:  disgust3099.jpg in the training set on the path:  /content/fer_images/train/disgust/disgust3099.jpg
# saved:  happy2572.jpg in the training set on the path:  /content/fer_images/train/happy/happy2572.jpg
# saved:  fear1996.jpg in the training set on the path:  /content/fer_images/train/fear/fear1996.jpg
# saved:  neutral4505.jpg in the training set on the path:  /content/fer_images/train/neutral/neutral4505.jpg
# saved:  surprise3167.jpg in the training set on the path:  /content/fer_images/train/surprise/surprise3167.jpg
# saved:  neutral4506.jpg in the training set on the path:  /content/fer_images/train/neutral/neutral4506.jpg
# saved:  fear1997.jpg in the training set on the path:  /content/fer_images/train/fear/fear1997.jpg
# saved:  neutral4507.jpg in the training set on the path:  /content/fer_images/train/neutral/neutral4507.jpg
# saved:  neutral4508.jpg in the training set on the path:  /content/fer_images/train/neutral/neutral4508.jpg
# saved:  angry2516.jpg in the training set on the path:  /content/fer_images/train/angry/angry2516.jpg
# saved:  angry2517.jpg in the training set on the path:  /content/fer_images/train/angry/angry2517.jpg
# saved:  angry2518.jpg in the training set on the path:  /content/fer_images/train/angry/angry2518.jpg
# saved:  disgust3100.jpg in the training set on the path:  /content/fer_images/train/disgust/disgust3100.jpg
# saved:  angry2519.jpg in the training set on the path:  /content/fer_images/train/angry/angry2519.jpg
# saved:  surprise3168.jpg in the training set on the path:  /content/fer_images/train/surprise/surprise3168.jpg
# saved:  happy2573.jpg in the training set on the path:  /content/fer_images/train/happy/happy2573.jpg
# saved:  happy2574.jpg in the training set on the path:  /content/fer_images/train/happy/happy2574.jpg
# saved:  neutral4509.jpg in the training set on the path:  /content/fer_images/train/neutral/neutral4509.jpg
# saved:  surprise3169.jpg in the training set on the path:  /content/fer_images/train/surprise/surprise3169.jpg
# saved:  neutral4510.jpg in the training set on the path:  /content/fer_images/train/neutral/neutral4510.jpg
# saved:  angry2520.jpg in the training set on the path:  /content/fer_images/train/angry/angry2520.jpg
# saved:  happy2575.jpg in the training set on the path:  /content/fer_images/train/happy/happy2575.jpg
# saved:  fear1998.jpg in the training set on the path:  /content/fer_images/train/fear/fear1998.jpg
# saved:  neutral4511.jpg in the training set on the path:  /content/fer_images/train/neutral/neutral4511.jpg
# saved:  happy2576.jpg in the training set on the path:  /content/fer_images/train/happy/happy2576.jpg
# saved:  disgust3101.jpg in the training set on the path:  /content/fer_images/train/disgust/disgust3101.jpg
# saved:  happy2577.jpg in the training set on the path:  /content/fer_images/train/happy/happy2577.jpg
# saved:  happy2578.jpg in the training set on the path:  /content/fer_images/train/happy/happy2578.jpg
# saved:  disgust3102.jpg in the training set on the path:  /content/fer_images/train/disgust/disgust3102.jpg
# saved:  fear1999.jpg in the training set on the path:  /content/fer_images/train/fear/fear1999.jpg
# saved:  happy2579.jpg in the training set on the path:  /content/fer_images/train/happy/happy2579.jpg
# saved:  surprise3170.jpg in the training set on the path:  /content/fer_images/train/surprise/surprise3170.jpg
# saved:  happy2580.jpg in the training set on the path:  /content/fer_images/train/happy/happy2580.jpg
# saved:  neutral4512.jpg in the training set on the path:  /content/fer_images/train/neutral/neutral4512.jpg
# saved:  fear2000.jpg in the training set on the path:  /content/fer_images/train/fear/fear2000.jpg
# saved:  happy2581.jpg in the training set on the path:  /content/fer_images/train/happy/happy2581.jpg
# saved:  fear2001.jpg in the training set on the path:  /content/fer_images/train/fear/fear2001.jpg
# saved:  neutral4513.jpg in the training set on the path:  /content/fer_images/train/neutral/neutral4513.jpg
# saved:  neutral4514.jpg in the training set on the path:  /content/fer_images/train/neutral/neutral4514.jpg
# saved:  disgust3103.jpg in the training set on the path:  /content/fer_images/train/disgust/disgust3103.jpg
# saved:  disgust3104.jpg in the training set on the path:  /content/fer_images/train/disgust/disgust3104.jpg
# saved:  angry2521.jpg in the training set on the path:  /content/fer_images/train/angry/angry2521.jpg
# saved:  angry2522.jpg in the training set on the path:  /content/fer_images/train/angry/angry2522.jpg
# saved:  surprise3171.jpg in the training set on the path:  /content/fer_images/train/surprise/surprise3171.jpg
# saved:  surprise3172.jpg in the training set on the path:  /content/fer_images/train/surprise/surprise3172.jpg
# saved:  surprise3173.jpg in the training set on the path:  /content/fer_images/train/surprise/surprise3173.jpg
# saved:  neutral4515.jpg in the training set on the path:  /content/fer_images/train/neutral/neutral4515.jpg
# saved:  neutral4516.jpg in the training set on the path:  /content/fer_images/train/neutral/neutral4516.jpg
# saved:  happy2582.jpg in the training set on the path:  /content/fer_images/train/happy/happy2582.jpg
# saved:  disgust3105.jpg in the training set on the path:  /content/fer_images/train/disgust/disgust3105.jpg
# saved:  angry2523.jpg in the training set on the path:  /content/fer_images/train/angry/angry2523.jpg
# saved:  neutral4517.jpg in the training set on the path:  /content/fer_images/train/neutral/neutral4517.jpg
# saved:  neutral4518.jpg in the training set on the path:  /content/fer_images/train/neutral/neutral4518.jpg
# saved:  disgust3106.jpg in the training set on the path:  /content/fer_images/train/disgust/disgust3106.jpg
# saved:  fear2002.jpg in the training set on the path:  /content/fer_images/train/fear/fear2002.jpg
# saved:  disgust3107.jpg in the training set on the path:  /content/fer_images/train/disgust/disgust3107.jpg
# saved:  disgust3108.jpg in the training set on the path:  /content/fer_images/train/disgust/disgust3108.jpg
# saved:  neutral4519.jpg in the training set on the path:  /content/fer_images/train/neutral/neutral4519.jpg
# saved:  surprise3174.jpg in the training set on the path:  /content/fer_images/train/surprise/surprise3174.jpg
# saved:  disgust3109.jpg in the training set on the path:  /content/fer_images/train/disgust/disgust3109.jpg
# saved:  disgust3110.jpg in the training set on the path:  /content/fer_images/train/disgust/disgust3110.jpg
# saved:  fear2003.jpg in the training set on the path:  /content/fer_images/train/fear/fear2003.jpg
# saved:  neutral4520.jpg in the training set on the path:  /content/fer_images/train/neutral/neutral4520.jpg
# saved:  neutral4521.jpg in the training set on the path:  /content/fer_images/train/neutral/neutral4521.jpg
# saved:  fear2004.jpg in the training set on the path:  /content/fer_images/train/fear/fear2004.jpg
# saved:  neutral4522.jpg in the training set on the path:  /content/fer_images/train/neutral/neutral4522.jpg
# saved:  disgust3111.jpg in the training set on the path:  /content/fer_images/train/disgust/disgust3111.jpg
# saved:  fear2005.jpg in the training set on the path:  /content/fer_images/train/fear/fear2005.jpg
# saved:  neutral4523.jpg in the training set on the path:  /content/fer_images/train/neutral/neutral4523.jpg
# saved:  neutral4524.jpg in the training set on the path:  /content/fer_images/train/neutral/neutral4524.jpg
# saved:  surprise3175.jpg in the training set on the path:  /content/fer_images/train/surprise/surprise3175.jpg
# saved:  neutral4525.jpg in the training set on the path:  /content/fer_images/train/neutral/neutral4525.jpg
# saved:  disgust3112.jpg in the training set on the path:  /content/fer_images/train/disgust/disgust3112.jpg
# saved:  neutral4526.jpg in the training set on the path:  /content/fer_images/train/neutral/neutral4526.jpg
# saved:  surprise3176.jpg in the training set on the path:  /content/fer_images/train/surprise/surprise3176.jpg
# saved:  fear2006.jpg in the training set on the path:  /content/fer_images/train/fear/fear2006.jpg
# saved:  neutral4527.jpg in the training set on the path:  /content/fer_images/train/neutral/neutral4527.jpg
# saved:  happy2583.jpg in the training set on the path:  /content/fer_images/train/happy/happy2583.jpg
# saved:  surprise3177.jpg in the training set on the path:  /content/fer_images/train/surprise/surprise3177.jpg
# saved:  fear2007.jpg in the training set on the path:  /content/fer_images/train/fear/fear2007.jpg
# saved:  neutral4528.jpg in the training set on the path:  /content/fer_images/train/neutral/neutral4528.jpg
# saved:  angry2524.jpg in the training set on the path:  /content/fer_images/train/angry/angry2524.jpg
# saved:  surprise3178.jpg in the training set on the path:  /content/fer_images/train/surprise/surprise3178.jpg
# saved:  angry2525.jpg in the training set on the path:  /content/fer_images/train/angry/angry2525.jpg
# saved:  surprise3179.jpg in the training set on the path:  /content/fer_images/train/surprise/surprise3179.jpg
# saved:  neutral4529.jpg in the training set on the path:  /content/fer_images/train/neutral/neutral4529.jpg
# saved:  surprise3180.jpg in the training set on the path:  /content/fer_images/train/surprise/surprise3180.jpg
# saved:  surprise3181.jpg in the training set on the path:  /content/fer_images/train/surprise/surprise3181.jpg
# saved:  neutral4530.jpg in the training set on the path:  /content/fer_images/train/neutral/neutral4530.jpg
# saved:  neutral4531.jpg in the training set on the path:  /content/fer_images/train/neutral/neutral4531.jpg
# saved:  disgust3113.jpg in the training set on the path:  /content/fer_images/train/disgust/disgust3113.jpg
# saved:  disgust3114.jpg in the training set on the path:  /content/fer_images/train/disgust/disgust3114.jpg
# saved:  happy2584.jpg in the training set on the path:  /content/fer_images/train/happy/happy2584.jpg
# saved:  neutral4532.jpg in the training set on the path:  /content/fer_images/train/neutral/neutral4532.jpg
# saved:  neutral4533.jpg in the training set on the path:  /content/fer_images/train/neutral/neutral4533.jpg
# saved:  happy2585.jpg in the training set on the path:  /content/fer_images/train/happy/happy2585.jpg
# saved:  fear2008.jpg in the training set on the path:  /content/fer_images/train/fear/fear2008.jpg
# saved:  neutral4534.jpg in the training set on the path:  /content/fer_images/train/neutral/neutral4534.jpg
# saved:  fear2009.jpg in the training set on the path:  /content/fer_images/train/fear/fear2009.jpg
# saved:  fear2010.jpg in the training set on the path:  /content/fer_images/train/fear/fear2010.jpg
# saved:  neutral4535.jpg in the training set on the path:  /content/fer_images/train/neutral/neutral4535.jpg
# saved:  surprise3182.jpg in the training set on the path:  /content/fer_images/train/surprise/surprise3182.jpg
# saved:  neutral4536.jpg in the training set on the path:  /content/fer_images/train/neutral/neutral4536.jpg
# saved:  surprise3183.jpg in the training set on the path:  /content/fer_images/train/surprise/surprise3183.jpg
# saved:  neutral4537.jpg in the training set on the path:  /content/fer_images/train/neutral/neutral4537.jpg
# saved:  fear2011.jpg in the training set on the path:  /content/fer_images/train/fear/fear2011.jpg
# saved:  neutral4538.jpg in the training set on the path:  /content/fer_images/train/neutral/neutral4538.jpg
# saved:  neutral4539.jpg in the training set on the path:  /content/fer_images/train/neutral/neutral4539.jpg
# saved:  neutral4540.jpg in the training set on the path:  /content/fer_images/train/neutral/neutral4540.jpg
# saved:  neutral4541.jpg in the training set on the path:  /content/fer_images/train/neutral/neutral4541.jpg
# saved:  surprise3184.jpg in the training set on the path:  /content/fer_images/train/surprise/surprise3184.jpg
# saved:  neutral4542.jpg in the training set on the path:  /content/fer_images/train/neutral/neutral4542.jpg
# saved:  surprise3185.jpg in the training set on the path:  /content/fer_images/train/surprise/surprise3185.jpg
# saved:  surprise3186.jpg in the training set on the path:  /content/fer_images/train/surprise/surprise3186.jpg
# saved:  disgust3115.jpg in the training set on the path:  /content/fer_images/train/disgust/disgust3115.jpg
# saved:  angry2526.jpg in the training set on the path:  /content/fer_images/train/angry/angry2526.jpg
# saved:  angry2527.jpg in the training set on the path:  /content/fer_images/train/angry/angry2527.jpg
# saved:  disgust3116.jpg in the training set on the path:  /content/fer_images/train/disgust/disgust3116.jpg
# saved:  surprise3187.jpg in the training set on the path:  /content/fer_images/train/surprise/surprise3187.jpg
# saved:  angry2528.jpg in the training set on the path:  /content/fer_images/train/angry/angry2528.jpg
# saved:  neutral4543.jpg in the training set on the path:  /content/fer_images/train/neutral/neutral4543.jpg
# saved:  fear2012.jpg in the training set on the path:  /content/fer_images/train/fear/fear2012.jpg
# saved:  neutral4544.jpg in the training set on the path:  /content/fer_images/train/neutral/neutral4544.jpg
# saved:  neutral4545.jpg in the training set on the path:  /content/fer_images/train/neutral/neutral4545.jpg
# saved:  happy2586.jpg in the training set on the path:  /content/fer_images/train/happy/happy2586.jpg
# saved:  angry2529.jpg in the training set on the path:  /content/fer_images/train/angry/angry2529.jpg
# saved:  fear2013.jpg in the training set on the path:  /content/fer_images/train/fear/fear2013.jpg
# saved:  neutral4546.jpg in the training set on the path:  /content/fer_images/train/neutral/neutral4546.jpg
# saved:  disgust3117.jpg in the training set on the path:  /content/fer_images/train/disgust/disgust3117.jpg
# saved:  neutral4547.jpg in the training set on the path:  /content/fer_images/train/neutral/neutral4547.jpg
# saved:  fear2014.jpg in the training set on the path:  /content/fer_images/train/fear/fear2014.jpg
# saved:  angry2530.jpg in the training set on the path:  /content/fer_images/train/angry/angry2530.jpg
# saved:  surprise3188.jpg in the training set on the path:  /content/fer_images/train/surprise/surprise3188.jpg
# saved:  neutral4548.jpg in the training set on the path:  /content/fer_images/train/neutral/neutral4548.jpg
# saved:  happy2587.jpg in the training set on the path:  /content/fer_images/train/happy/happy2587.jpg
# saved:  angry2531.jpg in the training set on the path:  /content/fer_images/train/angry/angry2531.jpg
# saved:  angry2532.jpg in the training set on the path:  /content/fer_images/train/angry/angry2532.jpg
# saved:  disgust3118.jpg in the training set on the path:  /content/fer_images/train/disgust/disgust3118.jpg
# saved:  angry2533.jpg in the training set on the path:  /content/fer_images/train/angry/angry2533.jpg
# saved:  surprise3189.jpg in the training set on the path:  /content/fer_images/train/surprise/surprise3189.jpg
# saved:  happy2588.jpg in the training set on the path:  /content/fer_images/train/happy/happy2588.jpg
# saved:  surprise3190.jpg in the training set on the path:  /content/fer_images/train/surprise/surprise3190.jpg
# saved:  neutral4549.jpg in the training set on the path:  /content/fer_images/train/neutral/neutral4549.jpg
# saved:  surprise3191.jpg in the training set on the path:  /content/fer_images/train/surprise/surprise3191.jpg
# saved:  fear2015.jpg in the training set on the path:  /content/fer_images/train/fear/fear2015.jpg
# saved:  neutral4550.jpg in the training set on the path:  /content/fer_images/train/neutral/neutral4550.jpg
# saved:  sad291.jpg in the training set on the path:  /content/fer_images/train/sad/sad291.jpg
# saved:  surprise3192.jpg in the training set on the path:  /content/fer_images/train/surprise/surprise3192.jpg
# saved:  angry2534.jpg in the training set on the path:  /content/fer_images/train/angry/angry2534.jpg
# saved:  angry2535.jpg in the training set on the path:  /content/fer_images/train/angry/angry2535.jpg
# saved:  surprise3193.jpg in the training set on the path:  /content/fer_images/train/surprise/surprise3193.jpg
# saved:  neutral4551.jpg in the training set on the path:  /content/fer_images/train/neutral/neutral4551.jpg
# saved:  happy2589.jpg in the training set on the path:  /content/fer_images/train/happy/happy2589.jpg
# saved:  happy2590.jpg in the training set on the path:  /content/fer_images/train/happy/happy2590.jpg
# saved:  neutral4552.jpg in the training set on the path:  /content/fer_images/train/neutral/neutral4552.jpg
# saved:  fear2016.jpg in the training set on the path:  /content/fer_images/train/fear/fear2016.jpg
# saved:  neutral4553.jpg in the training set on the path:  /content/fer_images/train/neutral/neutral4553.jpg
# saved:  disgust3119.jpg in the training set on the path:  /content/fer_images/train/disgust/disgust3119.jpg
# saved:  fear2017.jpg in the training set on the path:  /content/fer_images/train/fear/fear2017.jpg
# saved:  disgust3120.jpg in the training set on the path:  /content/fer_images/train/disgust/disgust3120.jpg
# saved:  neutral4554.jpg in the training set on the path:  /content/fer_images/train/neutral/neutral4554.jpg
# saved:  disgust3121.jpg in the training set on the path:  /content/fer_images/train/disgust/disgust3121.jpg
# saved:  neutral4555.jpg in the training set on the path:  /content/fer_images/train/neutral/neutral4555.jpg
# saved:  surprise3194.jpg in the training set on the path:  /content/fer_images/train/surprise/surprise3194.jpg
# saved:  surprise3195.jpg in the training set on the path:  /content/fer_images/train/surprise/surprise3195.jpg
# saved:  neutral4556.jpg in the training set on the path:  /content/fer_images/train/neutral/neutral4556.jpg
# saved:  happy2591.jpg in the training set on the path:  /content/fer_images/train/happy/happy2591.jpg
# saved:  neutral4557.jpg in the training set on the path:  /content/fer_images/train/neutral/neutral4557.jpg
# saved:  happy2592.jpg in the training set on the path:  /content/fer_images/train/happy/happy2592.jpg
# saved:  neutral4558.jpg in the training set on the path:  /content/fer_images/train/neutral/neutral4558.jpg
# saved:  angry2536.jpg in the training set on the path:  /content/fer_images/train/angry/angry2536.jpg
# saved:  angry2537.jpg in the training set on the path:  /content/fer_images/train/angry/angry2537.jpg
# saved:  neutral4559.jpg in the training set on the path:  /content/fer_images/train/neutral/neutral4559.jpg
# saved:  fear2018.jpg in the training set on the path:  /content/fer_images/train/fear/fear2018.jpg
# saved:  happy2593.jpg in the training set on the path:  /content/fer_images/train/happy/happy2593.jpg
# saved:  surprise3196.jpg in the training set on the path:  /content/fer_images/train/surprise/surprise3196.jpg
# saved:  neutral4560.jpg in the training set on the path:  /content/fer_images/train/neutral/neutral4560.jpg
# saved:  neutral4561.jpg in the training set on the path:  /content/fer_images/train/neutral/neutral4561.jpg
# saved:  neutral4562.jpg in the training set on the path:  /content/fer_images/train/neutral/neutral4562.jpg
# saved:  fear2019.jpg in the training set on the path:  /content/fer_images/train/fear/fear2019.jpg
# saved:  neutral4563.jpg in the training set on the path:  /content/fer_images/train/neutral/neutral4563.jpg
# saved:  neutral4564.jpg in the training set on the path:  /content/fer_images/train/neutral/neutral4564.jpg
# saved:  angry2538.jpg in the training set on the path:  /content/fer_images/train/angry/angry2538.jpg
# saved:  happy2594.jpg in the training set on the path:  /content/fer_images/train/happy/happy2594.jpg
# saved:  angry2539.jpg in the training set on the path:  /content/fer_images/train/angry/angry2539.jpg
# saved:  neutral4565.jpg in the training set on the path:  /content/fer_images/train/neutral/neutral4565.jpg
# saved:  disgust3122.jpg in the training set on the path:  /content/fer_images/train/disgust/disgust3122.jpg
# saved:  neutral4566.jpg in the training set on the path:  /content/fer_images/train/neutral/neutral4566.jpg
# saved:  neutral4567.jpg in the training set on the path:  /content/fer_images/train/neutral/neutral4567.jpg
# saved:  angry2540.jpg in the training set on the path:  /content/fer_images/train/angry/angry2540.jpg
# saved:  disgust3123.jpg in the training set on the path:  /content/fer_images/train/disgust/disgust3123.jpg
# saved:  happy2595.jpg in the training set on the path:  /content/fer_images/train/happy/happy2595.jpg
# saved:  neutral4568.jpg in the training set on the path:  /content/fer_images/train/neutral/neutral4568.jpg
# saved:  neutral4569.jpg in the training set on the path:  /content/fer_images/train/neutral/neutral4569.jpg
# saved:  neutral4570.jpg in the training set on the path:  /content/fer_images/train/neutral/neutral4570.jpg
# saved:  fear2020.jpg in the training set on the path:  /content/fer_images/train/fear/fear2020.jpg
# saved:  disgust3124.jpg in the training set on the path:  /content/fer_images/train/disgust/disgust3124.jpg
# saved:  disgust3125.jpg in the training set on the path:  /content/fer_images/train/disgust/disgust3125.jpg
# saved:  disgust3126.jpg in the training set on the path:  /content/fer_images/train/disgust/disgust3126.jpg
# saved:  neutral4571.jpg in the training set on the path:  /content/fer_images/train/neutral/neutral4571.jpg
# saved:  disgust3127.jpg in the training set on the path:  /content/fer_images/train/disgust/disgust3127.jpg
# saved:  happy2596.jpg in the training set on the path:  /content/fer_images/train/happy/happy2596.jpg
# saved:  surprise3197.jpg in the training set on the path:  /content/fer_images/train/surprise/surprise3197.jpg
# saved:  fear2021.jpg in the training set on the path:  /content/fer_images/train/fear/fear2021.jpg
# saved:  angry2541.jpg in the training set on the path:  /content/fer_images/train/angry/angry2541.jpg
# saved:  neutral4572.jpg in the training set on the path:  /content/fer_images/train/neutral/neutral4572.jpg
# saved:  surprise3198.jpg in the training set on the path:  /content/fer_images/train/surprise/surprise3198.jpg
# saved:  angry2542.jpg in the training set on the path:  /content/fer_images/train/angry/angry2542.jpg
# saved:  neutral4573.jpg in the training set on the path:  /content/fer_images/train/neutral/neutral4573.jpg
# saved:  neutral4574.jpg in the training set on the path:  /content/fer_images/train/neutral/neutral4574.jpg
# saved:  angry2543.jpg in the training set on the path:  /content/fer_images/train/angry/angry2543.jpg
# saved:  surprise3199.jpg in the training set on the path:  /content/fer_images/train/surprise/surprise3199.jpg
# saved:  surprise3200.jpg in the training set on the path:  /content/fer_images/train/surprise/surprise3200.jpg
# saved:  happy2597.jpg in the training set on the path:  /content/fer_images/train/happy/happy2597.jpg
# saved:  sad292.jpg in the training set on the path:  /content/fer_images/train/sad/sad292.jpg
# saved:  disgust3128.jpg in the training set on the path:  /content/fer_images/train/disgust/disgust3128.jpg
# saved:  surprise3201.jpg in the training set on the path:  /content/fer_images/train/surprise/surprise3201.jpg
# saved:  surprise3202.jpg in the training set on the path:  /content/fer_images/train/surprise/surprise3202.jpg
# saved:  happy2598.jpg in the training set on the path:  /content/fer_images/train/happy/happy2598.jpg
# saved:  angry2544.jpg in the training set on the path:  /content/fer_images/train/angry/angry2544.jpg
# saved:  surprise3203.jpg in the training set on the path:  /content/fer_images/train/surprise/surprise3203.jpg
# saved:  neutral4575.jpg in the training set on the path:  /content/fer_images/train/neutral/neutral4575.jpg
# saved:  neutral4576.jpg in the training set on the path:  /content/fer_images/train/neutral/neutral4576.jpg
# saved:  surprise3204.jpg in the training set on the path:  /content/fer_images/train/surprise/surprise3204.jpg
# saved:  happy2599.jpg in the training set on the path:  /content/fer_images/train/happy/happy2599.jpg
# saved:  neutral4577.jpg in the training set on the path:  /content/fer_images/train/neutral/neutral4577.jpg
# saved:  happy2600.jpg in the training set on the path:  /content/fer_images/train/happy/happy2600.jpg
# saved:  fear2022.jpg in the training set on the path:  /content/fer_images/train/fear/fear2022.jpg
# saved:  happy2601.jpg in the training set on the path:  /content/fer_images/train/happy/happy2601.jpg
# saved:  surprise3205.jpg in the training set on the path:  /content/fer_images/train/surprise/surprise3205.jpg
# saved:  angry2545.jpg in the training set on the path:  /content/fer_images/train/angry/angry2545.jpg
# saved:  angry2546.jpg in the training set on the path:  /content/fer_images/train/angry/angry2546.jpg
# saved:  neutral4578.jpg in the training set on the path:  /content/fer_images/train/neutral/neutral4578.jpg
# saved:  neutral4579.jpg in the training set on the path:  /content/fer_images/train/neutral/neutral4579.jpg
# saved:  neutral4580.jpg in the training set on the path:  /content/fer_images/train/neutral/neutral4580.jpg
# saved:  neutral4581.jpg in the training set on the path:  /content/fer_images/train/neutral/neutral4581.jpg
# saved:  surprise3206.jpg in the training set on the path:  /content/fer_images/train/surprise/surprise3206.jpg
# saved:  angry2547.jpg in the training set on the path:  /content/fer_images/train/angry/angry2547.jpg
# saved:  surprise3207.jpg in the training set on the path:  /content/fer_images/train/surprise/surprise3207.jpg
# saved:  angry2548.jpg in the training set on the path:  /content/fer_images/train/angry/angry2548.jpg
# saved:  surprise3208.jpg in the training set on the path:  /content/fer_images/train/surprise/surprise3208.jpg
# saved:  neutral4582.jpg in the training set on the path:  /content/fer_images/train/neutral/neutral4582.jpg
# saved:  happy2602.jpg in the training set on the path:  /content/fer_images/train/happy/happy2602.jpg
# saved:  angry2549.jpg in the training set on the path:  /content/fer_images/train/angry/angry2549.jpg
# saved:  disgust3129.jpg in the training set on the path:  /content/fer_images/train/disgust/disgust3129.jpg
# saved:  neutral4583.jpg in the training set on the path:  /content/fer_images/train/neutral/neutral4583.jpg
# saved:  disgust3130.jpg in the training set on the path:  /content/fer_images/train/disgust/disgust3130.jpg
# saved:  surprise3209.jpg in the training set on the path:  /content/fer_images/train/surprise/surprise3209.jpg
# saved:  happy2603.jpg in the training set on the path:  /content/fer_images/train/happy/happy2603.jpg
# saved:  angry2550.jpg in the training set on the path:  /content/fer_images/train/angry/angry2550.jpg
# saved:  disgust3131.jpg in the training set on the path:  /content/fer_images/train/disgust/disgust3131.jpg
# saved:  happy2604.jpg in the training set on the path:  /content/fer_images/train/happy/happy2604.jpg
# saved:  disgust3132.jpg in the training set on the path:  /content/fer_images/train/disgust/disgust3132.jpg
# saved:  happy2605.jpg in the training set on the path:  /content/fer_images/train/happy/happy2605.jpg
# saved:  neutral4584.jpg in the training set on the path:  /content/fer_images/train/neutral/neutral4584.jpg
# saved:  angry2551.jpg in the training set on the path:  /content/fer_images/train/angry/angry2551.jpg
# saved:  happy2606.jpg in the training set on the path:  /content/fer_images/train/happy/happy2606.jpg
# saved:  disgust3133.jpg in the training set on the path:  /content/fer_images/train/disgust/disgust3133.jpg
# saved:  neutral4585.jpg in the training set on the path:  /content/fer_images/train/neutral/neutral4585.jpg
# saved:  happy2607.jpg in the training set on the path:  /content/fer_images/train/happy/happy2607.jpg
# saved:  neutral4586.jpg in the training set on the path:  /content/fer_images/train/neutral/neutral4586.jpg
# saved:  neutral4587.jpg in the training set on the path:  /content/fer_images/train/neutral/neutral4587.jpg
# saved:  happy2608.jpg in the training set on the path:  /content/fer_images/train/happy/happy2608.jpg
# saved:  neutral4588.jpg in the training set on the path:  /content/fer_images/train/neutral/neutral4588.jpg
# saved:  fear2023.jpg in the training set on the path:  /content/fer_images/train/fear/fear2023.jpg
# saved:  fear2024.jpg in the training set on the path:  /content/fer_images/train/fear/fear2024.jpg
# saved:  happy2609.jpg in the training set on the path:  /content/fer_images/train/happy/happy2609.jpg
# saved:  angry2552.jpg in the training set on the path:  /content/fer_images/train/angry/angry2552.jpg
# saved:  fear2025.jpg in the training set on the path:  /content/fer_images/train/fear/fear2025.jpg
# saved:  neutral4589.jpg in the training set on the path:  /content/fer_images/train/neutral/neutral4589.jpg
# saved:  happy2610.jpg in the training set on the path:  /content/fer_images/train/happy/happy2610.jpg
# saved:  fear2026.jpg in the training set on the path:  /content/fer_images/train/fear/fear2026.jpg
# saved:  surprise3210.jpg in the training set on the path:  /content/fer_images/train/surprise/surprise3210.jpg
# saved:  angry2553.jpg in the training set on the path:  /content/fer_images/train/angry/angry2553.jpg
# saved:  fear2027.jpg in the training set on the path:  /content/fer_images/train/fear/fear2027.jpg
# saved:  fear2028.jpg in the training set on the path:  /content/fer_images/train/fear/fear2028.jpg
# saved:  sad293.jpg in the training set on the path:  /content/fer_images/train/sad/sad293.jpg
# saved:  neutral4590.jpg in the training set on the path:  /content/fer_images/train/neutral/neutral4590.jpg
# saved:  disgust3134.jpg in the training set on the path:  /content/fer_images/train/disgust/disgust3134.jpg
# saved:  happy2611.jpg in the training set on the path:  /content/fer_images/train/happy/happy2611.jpg
# saved:  happy2612.jpg in the training set on the path:  /content/fer_images/train/happy/happy2612.jpg
# ...
# saved:  disgust3855.jpg in the training set on the path:  /content/fer_images/train/disgust/disgust3855.jpg
# saved:  happy3221.jpg in the training set on the path:  /content/fer_images/train/happy/happy3221.jpg
# saved:  neutral5715.jpg in the training set on the path:  /content/fer_images/train/neutral/neutral5715.jpg
# saved:  neutral5716.jpg in the training set on the path:  /content/fer_images/train/neutral/neutral5716.jpg
# saved:  surprise3984.jpg in the training set on the path:  /content/fer_images/train/surprise/surprise3984.jpg
# saved:  disgust3856.jpg in the training set on the path:  /content/fer_images/train/disgust/disgust3856.jpg
# saved:  disgust3857.jpg in the training set on the path:  /content/fer_images/train/disgust/disgust3857.jpg
# saved:  disgust3858.jpg in the training set on the path:  /content/fer_images/train/disgust/disgust3858.jpg
# saved:  neutral5717.jpg in the training set on the path:  /content/fer_images/train/neutral/neutral5717.jpg
# saved:  disgust3859.jpg in the training set on the path:  /content/fer_images/train/disgust/disgust3859.jpg
# saved:  neutral5718.jpg in the training set on the path:  /content/fer_images/train/neutral/neutral5718.jpg
# saved:  disgust3860.jpg in the training set on the path:  /content/fer_images/train/disgust/disgust3860.jpg
# saved:  sad360.jpg in the training set on the path:  /content/fer_images/train/sad/sad360.jpg
# saved:  neutral5719.jpg in the training set on the path:  /content/fer_images/train/neutral/neutral5719.jpg
# saved:  fear2535.jpg in the training set on the path:  /content/fer_images/train/fear/fear2535.jpg
# saved:  surprise3985.jpg in the training set on the path:  /content/fer_images/train/surprise/surprise3985.jpg
# saved:  fear2536.jpg in the training set on the path:  /content/fer_images/train/fear/fear2536.jpg
# saved:  fear2537.jpg in the training set on the path:  /content/fer_images/train/fear/fear2537.jpg
# saved:  surprise3986.jpg in the training set on the path:  /content/fer_images/train/surprise/surprise3986.jpg
# saved:  surprise3987.jpg in the training set on the path:  /content/fer_images/train/surprise/surprise3987.jpg
# saved:  surprise3988.jpg in the training set on the path:  /content/fer_images/train/surprise/surprise3988.jpg
# saved:  fear2538.jpg in the training set on the path:  /content/fer_images/train/fear/fear2538.jpg
# saved:  disgust3861.jpg in the training set on the path:  /content/fer_images/train/disgust/disgust3861.jpg
# saved:  surprise3989.jpg in the training set on the path:  /content/fer_images/train/surprise/surprise3989.jpg
# saved:  angry3154.jpg in the training set on the path:  /content/fer_images/train/angry/angry3154.jpg
# saved:  disgust3862.jpg in the training set on the path:  /content/fer_images/train/disgust/disgust3862.jpg
# saved:  happy3222.jpg in the training set on the path:  /content/fer_images/train/happy/happy3222.jpg
# saved:  sad361.jpg in the training set on the path:  /content/fer_images/train/sad/sad361.jpg
# saved:  happy3223.jpg in the training set on the path:  /content/fer_images/train/happy/happy3223.jpg
# saved:  surprise3990.jpg in the training set on the path:  /content/fer_images/train/surprise/surprise3990.jpg
# saved:  surprise3991.jpg in the training set on the path:  /content/fer_images/train/surprise/surprise3991.jpg
# saved:  surprise3992.jpg in the training set on the path:  /content/fer_images/train/surprise/surprise3992.jpg
# saved:  neutral5720.jpg in the training set on the path:  /content/fer_images/train/neutral/neutral5720.jpg
# saved:  surprise3993.jpg in the training set on the path:  /content/fer_images/train/surprise/surprise3993.jpg
# saved:  neutral5721.jpg in the training set on the path:  /content/fer_images/train/neutral/neutral5721.jpg
# saved:  angry3155.jpg in the training set on the path:  /content/fer_images/train/angry/angry3155.jpg
# saved:  neutral5722.jpg in the training set on the path:  /content/fer_images/train/neutral/neutral5722.jpg
# saved:  disgust3863.jpg in the training set on the path:  /content/fer_images/train/disgust/disgust3863.jpg
# saved:  surprise3994.jpg in the training set on the path:  /content/fer_images/train/surprise/surprise3994.jpg
# saved:  fear2539.jpg in the training set on the path:  /content/fer_images/train/fear/fear2539.jpg
# saved:  fear2540.jpg in the training set on the path:  /content/fer_images/train/fear/fear2540.jpg
# saved:  happy3224.jpg in the training set on the path:  /content/fer_images/train/happy/happy3224.jpg
# saved:  surprise3995.jpg in the training set on the path:  /content/fer_images/train/surprise/surprise3995.jpg
# saved:  happy3225.jpg in the training set on the path:  /content/fer_images/train/happy/happy3225.jpg
# saved:  disgust3864.jpg in the training set on the path:  /content/fer_images/train/disgust/disgust3864.jpg
# saved:  happy3226.jpg in the training set on the path:  /content/fer_images/train/happy/happy3226.jpg
# saved:  neutral5723.jpg in the training set on the path:  /content/fer_images/train/neutral/neutral5723.jpg
# saved:  neutral5724.jpg in the training set on the path:  /content/fer_images/train/neutral/neutral5724.jpg
# saved:  surprise3996.jpg in the training set on the path:  /content/fer_images/train/surprise/surprise3996.jpg
# saved:  happy3227.jpg in the training set on the path:  /content/fer_images/train/happy/happy3227.jpg
# saved:  happy3228.jpg in the training set on the path:  /content/fer_images/train/happy/happy3228.jpg
# saved:  neutral5725.jpg in the training set on the path:  /content/fer_images/train/neutral/neutral5725.jpg
# saved:  happy3229.jpg in the training set on the path:  /content/fer_images/train/happy/happy3229.jpg
# saved:  neutral5726.jpg in the training set on the path:  /content/fer_images/train/neutral/neutral5726.jpg
# saved:  surprise3997.jpg in the training set on the path:  /content/fer_images/train/surprise/surprise3997.jpg
# saved:  angry3156.jpg in the training set on the path:  /content/fer_images/train/angry/angry3156.jpg
# saved:  neutral5727.jpg in the training set on the path:  /content/fer_images/train/neutral/neutral5727.jpg
# saved:  angry3157.jpg in the training set on the path:  /content/fer_images/train/angry/angry3157.jpg
# saved:  happy3230.jpg in the training set on the path:  /content/fer_images/train/happy/happy3230.jpg
# saved:  neutral5728.jpg in the training set on the path:  /content/fer_images/train/neutral/neutral5728.jpg
# saved:  happy3231.jpg in the training set on the path:  /content/fer_images/train/happy/happy3231.jpg
# saved:  happy3232.jpg in the training set on the path:  /content/fer_images/train/happy/happy3232.jpg
# saved:  disgust3865.jpg in the training set on the path:  /content/fer_images/train/disgust/disgust3865.jpg
# saved:  fear2541.jpg in the training set on the path:  /content/fer_images/train/fear/fear2541.jpg
# saved:  neutral5729.jpg in the training set on the path:  /content/fer_images/train/neutral/neutral5729.jpg
# saved:  surprise3998.jpg in the training set on the path:  /content/fer_images/train/surprise/surprise3998.jpg
# saved:  angry3158.jpg in the training set on the path:  /content/fer_images/train/angry/angry3158.jpg
# saved:  disgust3866.jpg in the training set on the path:  /content/fer_images/train/disgust/disgust3866.jpg
# saved:  neutral5730.jpg in the training set on the path:  /content/fer_images/train/neutral/neutral5730.jpg
# saved:  fear2542.jpg in the training set on the path:  /content/fer_images/train/fear/fear2542.jpg
# saved:  neutral5731.jpg in the training set on the path:  /content/fer_images/train/neutral/neutral5731.jpg
# saved:  surprise3999.jpg in the training set on the path:  /content/fer_images/train/surprise/surprise3999.jpg
# saved:  happy3233.jpg in the training set on the path:  /content/fer_images/train/happy/happy3233.jpg
# saved:  neutral5732.jpg in the training set on the path:  /content/fer_images/train/neutral/neutral5732.jpg
# saved:  surprise4000.jpg in the training set on the path:  /content/fer_images/train/surprise/surprise4000.jpg
# saved:  neutral5733.jpg in the training set on the path:  /content/fer_images/train/neutral/neutral5733.jpg
# saved:  fear2543.jpg in the training set on the path:  /content/fer_images/train/fear/fear2543.jpg
# saved:  angry3159.jpg in the training set on the path:  /content/fer_images/train/angry/angry3159.jpg
# saved:  happy3234.jpg in the training set on the path:  /content/fer_images/train/happy/happy3234.jpg
# saved:  surprise4001.jpg in the training set on the path:  /content/fer_images/train/surprise/surprise4001.jpg
# saved:  angry3160.jpg in the training set on the path:  /content/fer_images/train/angry/angry3160.jpg
# saved:  surprise4002.jpg in the training set on the path:  /content/fer_images/train/surprise/surprise4002.jpg
# saved:  neutral5734.jpg in the training set on the path:  /content/fer_images/train/neutral/neutral5734.jpg
# saved:  disgust3867.jpg in the training set on the path:  /content/fer_images/train/disgust/disgust3867.jpg
# saved:  surprise4003.jpg in the training set on the path:  /content/fer_images/train/surprise/surprise4003.jpg
# saved:  surprise4004.jpg in the training set on the path:  /content/fer_images/train/surprise/surprise4004.jpg
# saved:  happy3235.jpg in the training set on the path:  /content/fer_images/train/happy/happy3235.jpg
# saved:  disgust3868.jpg in the training set on the path:  /content/fer_images/train/disgust/disgust3868.jpg
# saved:  disgust3869.jpg in the training set on the path:  /content/fer_images/train/disgust/disgust3869.jpg
# saved:  happy3236.jpg in the training set on the path:  /content/fer_images/train/happy/happy3236.jpg
# saved:  surprise4005.jpg in the training set on the path:  /content/fer_images/train/surprise/surprise4005.jpg
# saved:  surprise4006.jpg in the training set on the path:  /content/fer_images/train/surprise/surprise4006.jpg
# saved:  surprise4007.jpg in the training set on the path:  /content/fer_images/train/surprise/surprise4007.jpg
# saved:  disgust3870.jpg in the training set on the path:  /content/fer_images/train/disgust/disgust3870.jpg
# saved:  disgust3871.jpg in the training set on the path:  /content/fer_images/train/disgust/disgust3871.jpg
# saved:  neutral5735.jpg in the training set on the path:  /content/fer_images/train/neutral/neutral5735.jpg
# saved:  sad362.jpg in the training set on the path:  /content/fer_images/train/sad/sad362.jpg
# saved:  surprise4008.jpg in the training set on the path:  /content/fer_images/train/surprise/surprise4008.jpg
# saved:  neutral5736.jpg in the training set on the path:  /content/fer_images/train/neutral/neutral5736.jpg
# saved:  happy3237.jpg in the training set on the path:  /content/fer_images/train/happy/happy3237.jpg
# saved:  neutral5737.jpg in the training set on the path:  /content/fer_images/train/neutral/neutral5737.jpg
# saved:  neutral5738.jpg in the training set on the path:  /content/fer_images/train/neutral/neutral5738.jpg
# saved:  neutral5739.jpg in the training set on the path:  /content/fer_images/train/neutral/neutral5739.jpg
# saved:  surprise4009.jpg in the training set on the path:  /content/fer_images/train/surprise/surprise4009.jpg
# saved:  fear2544.jpg in the training set on the path:  /content/fer_images/train/fear/fear2544.jpg
# saved:  angry3161.jpg in the training set on the path:  /content/fer_images/train/angry/angry3161.jpg
# saved:  disgust3872.jpg in the training set on the path:  /content/fer_images/train/disgust/disgust3872.jpg
# saved:  surprise4010.jpg in the training set on the path:  /content/fer_images/train/surprise/surprise4010.jpg
# saved:  neutral5740.jpg in the training set on the path:  /content/fer_images/train/neutral/neutral5740.jpg
# saved:  fear2545.jpg in the training set on the path:  /content/fer_images/train/fear/fear2545.jpg
# saved:  neutral5741.jpg in the training set on the path:  /content/fer_images/train/neutral/neutral5741.jpg
# saved:  surprise4011.jpg in the training set on the path:  /content/fer_images/train/surprise/surprise4011.jpg
# saved:  fear2546.jpg in the training set on the path:  /content/fer_images/train/fear/fear2546.jpg
# saved:  angry3162.jpg in the training set on the path:  /content/fer_images/train/angry/angry3162.jpg
# saved:  angry3163.jpg in the training set on the path:  /content/fer_images/train/angry/angry3163.jpg
# saved:  fear2547.jpg in the training set on the path:  /content/fer_images/train/fear/fear2547.jpg
# saved:  neutral5742.jpg in the training set on the path:  /content/fer_images/train/neutral/neutral5742.jpg
# saved:  surprise4012.jpg in the training set on the path:  /content/fer_images/train/surprise/surprise4012.jpg
# saved:  neutral5743.jpg in the training set on the path:  /content/fer_images/train/neutral/neutral5743.jpg
# saved:  fear2548.jpg in the training set on the path:  /content/fer_images/train/fear/fear2548.jpg
# saved:  surprise4013.jpg in the training set on the path:  /content/fer_images/train/surprise/surprise4013.jpg
# saved:  fear2549.jpg in the training set on the path:  /content/fer_images/train/fear/fear2549.jpg
# saved:  fear2550.jpg in the training set on the path:  /content/fer_images/train/fear/fear2550.jpg
# saved:  angry3164.jpg in the training set on the path:  /content/fer_images/train/angry/angry3164.jpg
# saved:  disgust3873.jpg in the training set on the path:  /content/fer_images/train/disgust/disgust3873.jpg
# saved:  fear2551.jpg in the training set on the path:  /content/fer_images/train/fear/fear2551.jpg
# saved:  angry3165.jpg in the training set on the path:  /content/fer_images/train/angry/angry3165.jpg
# saved:  disgust3874.jpg in the training set on the path:  /content/fer_images/train/disgust/disgust3874.jpg
# saved:  fear2552.jpg in the training set on the path:  /content/fer_images/train/fear/fear2552.jpg
# saved:  surprise4014.jpg in the training set on the path:  /content/fer_images/train/surprise/surprise4014.jpg
# saved:  neutral5744.jpg in the training set on the path:  /content/fer_images/train/neutral/neutral5744.jpg
# saved:  happy3238.jpg in the training set on the path:  /content/fer_images/train/happy/happy3238.jpg
# saved:  surprise4015.jpg in the training set on the path:  /content/fer_images/train/surprise/surprise4015.jpg
# saved:  neutral5745.jpg in the training set on the path:  /content/fer_images/train/neutral/neutral5745.jpg
# saved:  surprise4016.jpg in the training set on the path:  /content/fer_images/train/surprise/surprise4016.jpg
# saved:  disgust3875.jpg in the training set on the path:  /content/fer_images/train/disgust/disgust3875.jpg
# saved:  surprise4017.jpg in the training set on the path:  /content/fer_images/train/surprise/surprise4017.jpg
# saved:  neutral5746.jpg in the training set on the path:  /content/fer_images/train/neutral/neutral5746.jpg
# saved:  neutral5747.jpg in the training set on the path:  /content/fer_images/train/neutral/neutral5747.jpg
# saved:  neutral5748.jpg in the training set on the path:  /content/fer_images/train/neutral/neutral5748.jpg
# saved:  disgust3876.jpg in the training set on the path:  /content/fer_images/train/disgust/disgust3876.jpg
# saved:  neutral5749.jpg in the training set on the path:  /content/fer_images/train/neutral/neutral5749.jpg
# saved:  neutral5750.jpg in the training set on the path:  /content/fer_images/train/neutral/neutral5750.jpg
# saved:  angry3166.jpg in the training set on the path:  /content/fer_images/train/angry/angry3166.jpg
# saved:  disgust3877.jpg in the training set on the path:  /content/fer_images/train/disgust/disgust3877.jpg
# saved:  disgust3878.jpg in the training set on the path:  /content/fer_images/train/disgust/disgust3878.jpg
# saved:  surprise4018.jpg in the training set on the path:  /content/fer_images/train/surprise/surprise4018.jpg
# saved:  disgust3879.jpg in the training set on the path:  /content/fer_images/train/disgust/disgust3879.jpg
# saved:  surprise4019.jpg in the training set on the path:  /content/fer_images/train/surprise/surprise4019.jpg
# saved:  neutral5751.jpg in the training set on the path:  /content/fer_images/train/neutral/neutral5751.jpg

# %%
##saving each images on the validation set
counter_each = {'angry': 0, 'sad': 0, 'happy': 0, 'neutral': 0, 'disgust': 0, 'fear': 0, 'surprise': 0}
for (ind, row) in new_val.iterrows():
  emotion = em_dict[row['emotion']]
  emotion_path = os.path.join(validation_path, emotion)
  img = np.fromstring(row['pixels'], dtype='uint8', sep=' ')
  img = img.reshape((48, 48))
  image = Image.fromarray(img)
  counter_each[emotion] += 1
  filename = f'{emotion}{counter_each[emotion]}.jpg'
  image_path = os.path.join(emotion_path, filename)  
  image.save(image_path)
  print('saved: ', filename, 'in the validation set on the path: ', image_path)
# Out:
# Streaming output truncated to the last 5000 lines.
# saved:  disgust116.jpg in the validation set on the path:  /content/fer_images/validation/disgust/disgust116.jpg
# saved:  disgust117.jpg in the validation set on the path:  /content/fer_images/validation/disgust/disgust117.jpg
# saved:  neutral194.jpg in the validation set on the path:  /content/fer_images/validation/neutral/neutral194.jpg
# saved:  fear78.jpg in the validation set on the path:  /content/fer_images/validation/fear/fear78.jpg
# saved:  surprise131.jpg in the validation set on the path:  /content/fer_images/validation/surprise/surprise131.jpg
# saved:  sad10.jpg in the validation set on the path:  /content/fer_images/validation/sad/sad10.jpg
# saved:  disgust118.jpg in the validation set on the path:  /content/fer_images/validation/disgust/disgust118.jpg
# saved:  disgust119.jpg in the validation set on the path:  /content/fer_images/validation/disgust/disgust119.jpg
# saved:  disgust120.jpg in the validation set on the path:  /content/fer_images/validation/disgust/disgust120.jpg
# saved:  happy124.jpg in the validation set on the path:  /content/fer_images/validation/happy/happy124.jpg
# saved:  angry96.jpg in the validation set on the path:  /content/fer_images/validation/angry/angry96.jpg
# saved:  neutral195.jpg in the validation set on the path:  /content/fer_images/validation/neutral/neutral195.jpg
# saved:  surprise132.jpg in the validation set on the path:  /content/fer_images/validation/surprise/surprise132.jpg
# saved:  happy125.jpg in the validation set on the path:  /content/fer_images/validation/happy/happy125.jpg
# saved:  angry97.jpg in the validation set on the path:  /content/fer_images/validation/angry/angry97.jpg
# saved:  happy126.jpg in the validation set on the path:  /content/fer_images/validation/happy/happy126.jpg
# saved:  surprise133.jpg in the validation set on the path:  /content/fer_images/validation/surprise/surprise133.jpg
# saved:  fear79.jpg in the validation set on the path:  /content/fer_images/validation/fear/fear79.jpg
# saved:  angry98.jpg in the validation set on the path:  /content/fer_images/validation/angry/angry98.jpg
# saved:  happy127.jpg in the validation set on the path:  /content/fer_images/validation/happy/happy127.jpg
# saved:  disgust121.jpg in the validation set on the path:  /content/fer_images/validation/disgust/disgust121.jpg
# saved:  disgust122.jpg in the validation set on the path:  /content/fer_images/validation/disgust/disgust122.jpg
# saved:  happy128.jpg in the validation set on the path:  /content/fer_images/validation/happy/happy128.jpg
# saved:  disgust123.jpg in the validation set on the path:  /content/fer_images/validation/disgust/disgust123.jpg
# saved:  neutral196.jpg in the validation set on the path:  /content/fer_images/validation/neutral/neutral196.jpg
# saved:  surprise134.jpg in the validation set on the path:  /content/fer_images/validation/surprise/surprise134.jpg
# saved:  surprise135.jpg in the validation set on the path:  /content/fer_images/validation/surprise/surprise135.jpg
# saved:  angry99.jpg in the validation set on the path:  /content/fer_images/validation/angry/angry99.jpg
# saved:  neutral197.jpg in the validation set on the path:  /content/fer_images/validation/neutral/neutral197.jpg
# saved:  neutral198.jpg in the validation set on the path:  /content/fer_images/validation/neutral/neutral198.jpg
# saved:  angry100.jpg in the validation set on the path:  /content/fer_images/validation/angry/angry100.jpg
# saved:  surprise136.jpg in the validation set on the path:  /content/fer_images/validation/surprise/surprise136.jpg
# saved:  neutral199.jpg in the validation set on the path:  /content/fer_images/validation/neutral/neutral199.jpg
# saved:  neutral200.jpg in the validation set on the path:  /content/fer_images/validation/neutral/neutral200.jpg
# saved:  neutral201.jpg in the validation set on the path:  /content/fer_images/validation/neutral/neut
jpg in the validation set on the path:  /content/fer_images/validation/neutral/neutral1459.jpg
# saved:  surprise943.jpg in the validation set on the path:  /content/fer_images/validation/surprise/surprise943.jpg
# saved:  angry826.jpg in the validation set on the path:  /content/fer_images/validation/angry/angry826.jpg
# saved:  fear615.jpg in the validation set on the path:  /content/fer_images/validation/fear/fear615.jpg
# saved:  fear616.jpg in the validation set on the path:  /content/fer_images/validation/fear/fear616.jpg
# saved:  fear617.jpg in the validation set on the path:  /content/fer_images/validation/fear/fear617.jpg
# saved:  angry827.jpg in the validation set on the path:  /content/fer_images/validation/angry/angry827.jpg
# saved:  disgust947.jpg in the validation set on the path:  /content/fer_images/validation/disgust/disgust947.jpg
# saved:  sad74.jpg in the validation set on the path:  /content/fer_images/validation/sad/sad74.jpg
# saved:  disgust948.jpg in the validation set on the path:  /content/fer_images/validation/disgust/disgust948.jpg
# saved:  angry828.jpg in the validation set on the path:  /content/fer_images/validation/angry/angry828.jpg
# saved:  surprise944.jpg in the validation set on the path:  /content/fer_images/validation/surprise/surprise944.jpg
# saved:  fear618.jpg in the validation set on the path:  /content/fer_images/validation/fear/fear618.jpg
# saved:  neutral1460.jpg in the validation set on the path:  /content/fer_images/validation/neutral/neutral1460.jpg
# saved:  disgust949.jpg in the validation set on the path:  /content/fer_images/validation/disgust/disgust949.jpg
# saved:  disgust950.jpg in the validation set on the path:  /content/fer_images/validation/disgust/disgust950.jpg
# saved:  neutral1461.jpg in the validation set on the path:  /content/fer_images/validation/neutral/neutral1461.jpg
# saved:  neutral1462.jpg in the validation set on the path:  /content/fer_images/validation/neutral/neutral1462.jpg
# saved:  neutral1463.jpg in the validation set on the path:  /content/fer_images/validation/neutral/neutral1463.jpg
# saved:  angry829.jpg in the validation set on the path:  /content/fer_images/validation/angry/angry829.jpg
# saved:  disgust951.jpg in the validation set on the path:  /content/fer_images/validation/disgust/disgust951.jpg
# saved:  surprise945.jpg in the validation set on the path:  /content/fer_images/validation/surprise/surprise945.jpg
# saved:  surprise946.jpg in the validation set on the path:  /content/fer_images/validation/surprise/surprise946.jpg
# saved:  fear619.jpg in the validation set on the path:  /content/fer_images/validation/fear/fear619.jpg
# saved:  neutral1464.jpg in the validation set on the path:  /content/fer_images/validation/neutral/neutral1464.jpg

# %%
#hyperparameters
lr = 1e-3
batch_size = 32
epochs = 15

#device
device = 'cpu'
if torch.cuda.is_available():
  device = 'cuda'
  print('GPU available')
else:
  print('training is done on CPU')
# Out:
# GPU available

# %%
#now let's load the dataset into the 'dataloader' package of pytorch
from torchvision.datasets import ImageFolder
import torchvision.transforms as T

# %%
#first step is creating an augmentation cell using transforms of pytorch
train_augs = T.Compose([T.RandomHorizontalFlip(p=0.5), 
                        T.RandomRotation(degrees=(-20, +20)), 
                        T.ToTensor()])

valid_augs = T.Compose([T.ToTensor()])

# %%
trainset = ImageFolder(train_path, transform=train_augs)
validset = ImageFolder(validation_path, transform=valid_augs)
print(f"Total no. of examples in trainset : {len(trainset)}")
print(f"Total no. of examples in validset : {len(validset)}")
# Out:
# Total no. of examples in trainset : 22967
# Total no. of examples in validset : 5742

# %%
print(trainset.class_to_idx)
# Out:
# {'angry': 0, 'disgust': 1, 'fear': 2, 'happy': 3, 'neutral': 4, 'sad': 5, 'surprise': 6}

# %%
#we can view some images and their labels
import matplotlib.pyplot as plt
idx = np.random.randint(low=0, high=len(trainset)-1)
print('chosen index: ', idx)
image, label = trainset[idx] # the image has format of h, w, c -> so it have to be reshaped
plt.imshow(image.permute(1, 2, 0))
plt.title(label)
# Out:
# chosen index:  2916
# Text(0.5, 1.0, '0')

# %%
#now let's read the dataset using pytorch's dataloader
trainloader = DataLoader(trainset, batch_size=batch_size, shuffle=True)
validloader = DataLoader(validset, batch_size=batch_size)
print('total batches in trainloader: ', len(trainloader), 'and validloader: ', len(validloader))
# Out:
# total batches in trainloader:  718 and validloader:  180

# %%
#checking the shapes of each batch
for images, labels in trainloader:
  break
print(f'shape of a batch of images: {images.shape}')
print(f'shape of a batch of labels: {labels.shape}')
# Out:
# shape of a batch of images: torch.Size([32, 3, 48, 48])
# shape of a batch of labels: torch.Size([32])

# %%
#create a model
import timm
from torch import nn as nn
from torchvision import models
class FacialClassification(nn.Module):

  def __init__(self):
    super(FacialClassification, self).__init__()

    self.resnet50 = timm.create_model('resnet50', pretrained=True, num_classes=7)
  
  def forward(self, images, labels=None):
    scores = self.resnet50(images)
    if labels!=None:
      loss = nn.CrossEntropyLoss()(scores, labels)
      return scores, loss
    return scores

# %%
model = FacialClassification()
model.to(device)
# Out:
# Downloading: "https://github.com/rwightman/pytorch-image-models/releases/download/v0.1-rsb-weights/resnet50_a1_0-14fe96d1.pth" to /root/.cache/torch/hub/checkpoints/resnet50_a1_0-14fe96d1.pth
# FacialClassification(
#   (resnet50): ResNet(
#     (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#     (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (act1): ReLU(inplace=True)
#     (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (layer1): Sequential(
#       (0): Bottleneck(
#         (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act1): ReLU(inplace=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act2): ReLU(inplace=True)
#         (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act3): ReLU(inplace=True)
#         (downsample): Sequential(
#           (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): Bottleneck(
#         (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act1): ReLU(inplace=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act2): ReLU(inplace=True)
#         (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act3): ReLU(inplace=True)
#       )
#       (2): Bottleneck(
#         (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act1): ReLU(inplace=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act2): ReLU(inplace=True)
#         (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act3): ReLU(inplace=True)
#       )
#     )
#     (layer2): Sequential(
#       (0): Bottleneck(
#         (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act1): ReLU(inplace=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act2): ReLU(inplace=True)
#         (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act3): ReLU(inplace=True)
#         (downsample): Sequential(
#           (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): Bottleneck(
#         (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act1): ReLU(inplace=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act2): ReLU(inplace=True)
#         (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act3): ReLU(inplace=True)
#       )
#       (2): Bottleneck(
#         (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act1): ReLU(inplace=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act2): ReLU(inplace=True)
#         (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act3): ReLU(inplace=True)
#       )
#       (3): Bottleneck(
#         (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act1): ReLU(inplace=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act2): ReLU(inplace=True)
#         (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act3): ReLU(inplace=True)
#       )
#     )
#     (layer3): Sequential(
#       (0): Bottleneck(
#         (conv1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act1): ReLU(inplace=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act2): ReLU(inplace=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act3): ReLU(inplace=True)
#         (downsample): Sequential(
#           (0): Conv2d(512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act1): ReLU(inplace=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act2): ReLU(inplace=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act3): ReLU(inplace=True)
#       )
#       (2): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act1): ReLU(inplace=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act2): ReLU(inplace=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act3): ReLU(inplace=True)
#       )
#       (3): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act1): ReLU(inplace=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act2): ReLU(inplace=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act3): ReLU(inplace=True)
#       )
#       (4): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act1): ReLU(inplace=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act2): ReLU(inplace=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act3): ReLU(inplace=True)
#       )
#       (5): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act1): ReLU(inplace=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act2): ReLU(inplace=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act3): ReLU(inplace=True)
#       )
#     )
#     (layer4): Sequential(
#       (0): Bottleneck(
#         (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act1): ReLU(inplace=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act2): ReLU(inplace=True)
#         (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act3): ReLU(inplace=True)
#         (downsample): Sequential(
#           (0): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): Bottleneck(
#         (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act1): ReLU(inplace=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act2): ReLU(inplace=True)
#         (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act3): ReLU(inplace=True)
#       )
#       (2): Bottleneck(
#         (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act1): ReLU(inplace=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act2): ReLU(inplace=True)
#         (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act3): ReLU(inplace=True)
#       )
#     )
#     (global_pool): SelectAdaptivePool2d (pool_type=avg, flatten=Flatten(start_dim=1, end_dim=-1))
#     (fc): Linear(in_features=2048, out_features=7, bias=True)
#   )
# )

# %%
#accuracy of the model
from tqdm import tqdm
def multiclass_accuracy(y_pred,y_true):
    top_p,top_class = y_pred.topk(1,dim = 1)
    equals = top_class == y_true.view(*top_class.shape)
    return torch.mean(equals.type(torch.FloatTensor))

# %%
#building the train and eval functions (training the model on the training and on the validation set)
def train_model(model, dataloader, optimizer, current_epoch):

  model.train()
  total_loss = 0.0
  total_acc = 0.0
  tk = tqdm(dataloader, desc='EPOCH' + '[TRAIN]' + str(current_epoch + 1) + "/" + str(epochs))

  for t, data in enumerate(tk):
    images, labels = data
    images, labels = images.to(device), labels.to(device)

    optimizer.zero_grad()
    logits, loss = model(images, labels)
    loss.backward()
    optimizer.step()

    total_loss += loss.item()
    total_acc += multiclass_accuracy(logits, labels)
    tk.set_postfix({'loss': float(total_loss/(t+1)),'acc': float(total_acc/(t+1))})
  return total_loss/len(dataloader), total_acc / len(dataloader)

def eval_model(model, dataloader, current_epoch):

  model.eval()
  total_loss = 0.0
  total_acc = 0.0
  tk = tqdm(dataloader, desc='EPOCH' + '[VALID]' + str(current_epoch + 1) + "/" + str(epochs))

  for t, data in enumerate(tk):
    images, labels = data
    images, labels = images.to(device), labels.to(device)

    optimizer.zero_grad()
    logits, loss = model(images, labels)
    loss.backward()
    optimizer.step()

    total_loss += loss.item()
    total_acc += multiclass_accuracy(logits, labels)
    tk.set_postfix({'loss': float(total_loss/(t+1)),'acc': float(total_acc/(t+1))})
  return total_loss/len(dataloader), total_acc / len(dataloader)

# %%
#now let's train the model
from torch import optim
optimizer = optim.Adam(model.parameters(), lr=lr)

# %%
best_valid_loss = np.Inf
for i in range(epochs):
  train_loss, train_acc = train_model(model, trainloader, optimizer, i)
  valid_loss, valid_acc = eval_model(model, validloader, i)

  if valid_loss < best_valid_loss:
    torch.save(model.state_dict(), 'best-weights.pt')
    print('SAVED BEST WEIGHTS')
    best_valid_loss = valid_loss
print()
print()
print('accuracy on the training set: ', float(train_acc))
print('accuracy on the validation set: ', float(valid_acc))
# Out:
# EPOCH[TRAIN]1/15: 100%|██████████| 718/718 [01:49<00:00,  6.55it/s, loss=1.52, acc=0.41]
# EPOCH[VALID]1/15: 100%|██████████| 180/180 [00:26<00:00,  6.85it/s, loss=167, acc=0.874]
# SAVED BEST WEIGHTS
# EPOCH[TRAIN]2/15: 100%|██████████| 718/718 [01:47<00:00,  6.69it/s, loss=1.31, acc=0.496]
# EPOCH[VALID]2/15: 100%|██████████| 180/180 [00:26<00:00,  6.90it/s, loss=1.45, acc=0.929]
# SAVED BEST WEIGHTS
# EPOCH[TRAIN]3/15: 100%|██████████| 718/718 [01:46<00:00,  6.72it/s, loss=1.2, acc=0.547]
# EPOCH[VALID]3/15: 100%|██████████| 180/180 [00:26<00:00,  6.91it/s, loss=5.49, acc=0.887]
# EPOCH[TRAIN]4/15: 100%|██████████| 718/718 [01:46<00:00,  6.73it/s, loss=1.14, acc=0.57]
# EPOCH[VALID]4/15: 100%|██████████| 180/180 [00:26<00:00,  6.90it/s, loss=1.92, acc=0.867]
# EPOCH[TRAIN]5/15: 100%|██████████| 718/718 [01:46<00:00,  6.74it/s, loss=1.09, acc=0.59]
# EPOCH[VALID]5/15: 100%|██████████| 180/180 [00:25<00:00,  6.94it/s, loss=2.14, acc=0.893]
# EPOCH[TRAIN]6/15: 100%|██████████| 718/718 [01:46<00:00,  6.74it/s, loss=1.04, acc=0.606]
# EPOCH[VALID]6/15: 100%|██████████| 180/180 [00:26<00:00,  6.92it/s, loss=1.55, acc=0.886]
# EPOCH[TRAIN]7/15: 100%|██████████| 718/718 [01:46<00:00,  6.74it/s, loss=0.99, acc=0.627]
# EPOCH[VALID]7/15: 100%|██████████| 180/180 [00:26<00:00,  6.91it/s, loss=2.01, acc=0.858]
# EPOCH[TRAIN]8/15: 100%|██████████| 718/718 [01:46<00:00,  6.73it/s, loss=0.964, acc=0.639]
# EPOCH[VALID]8/15: 100%|██████████| 180/180 [00:26<00:00,  6.90it/s, loss=1.15, acc=0.803]
# SAVED BEST WEIGHTS
# EPOCH[TRAIN]9/15: 100%|██████████| 718/718 [01:46<00:00,  6.73it/s, loss=0.92, acc=0.654]
# EPOCH[VALID]9/15: 100%|██████████| 180/180 [00:26<00:00,  6.91it/s, loss=1.49, acc=0.64]
# EPOCH[TRAIN]10/15: 100%|██████████| 718/718 [01:46<00:00,  6.75it/s, loss=0.896, acc=0.664]
# EPOCH[VALID]10/15: 100%|██████████| 180/180 [00:25<00:00,  6.93it/s, loss=1.33, acc=0.555]
# EPOCH[TRAIN]11/15: 100%|██████████| 718/718 [01:46<00:00,  6.75it/s, loss=0.866, acc=0.675]
# EPOCH[VALID]11/15: 100%|██████████| 180/180 [00:26<00:00,  6.92it/s, loss=2.99, acc=0.915]
# EPOCH[TRAIN]12/15: 100%|██████████| 718/718 [01:46<00:00,  6.73it/s, loss=0.833, acc=0.688]
# EPOCH[VALID]12/15: 100%|██████████| 180/180 [00:26<00:00,  6.91it/s, loss=5.54, acc=0.901]
# EPOCH[TRAIN]13/15: 100%|██████████| 718/718 [01:46<00:00,  6.73it/s, loss=0.814, acc=0.697]
# EPOCH[VALID]13/15: 100%|██████████| 180/180 [00:26<00:00,  6.91it/s, loss=1.76, acc=0.921]
# EPOCH[TRAIN]14/15: 100%|██████████| 718/718 [01:46<00:00,  6.73it/s, loss=0.772, acc=0.712]
# EPOCH[VALID]14/15: 100%|██████████| 180/180 [00:26<00:00,  6.90it/s, loss=1.04, acc=0.9]
# SAVED BEST WEIGHTS
# EPOCH[TRAIN]15/15: 100%|██████████| 718/718 [01:46<00:00,  6.73it/s, loss=0.747, acc=0.721]
# EPOCH[VALID]15/15: 100%|██████████| 180/180 [00:25<00:00,  6.93it/s, loss=1.17, acc=0.894]
# accuracy on the training set:  0.7209981083869934
# accuracy on the validation set:  0.893750011920929
